# %% [markdown]
# ### Data Set Description
#
# This provides a quick description of the data set. This only goes over the training set and will cover its size, memory footprint, data type, summary statistics, and any distribution plots.

# %%
# Open data set
madelonURL <- "http://archive.ics.uci.edu/ml/machine-learning-databases/madelon/MADELON/madelon_train.data"
data <- read.csv(url(madelonURL), sep = " ", header = FALSE)
data$V501 <- NULL #Gets ride of the final NA column
head(data)
# Out:
#   V1  V2  V3  V4  V5  V6  V7  V8  V9  V10 ... V491 V492 V493 V494 V495 V496
# 1 485 477 537 479 452 471 491 476 475 473 ... 477  481  477  485  511  485
# 2 483 458 460 487 587 475 526 479 485 469 ... 463  478  487  338  513  486
# 3 487 542 499 468 448 471 442 478 480 477 ... 487  481  492  650  506  501
# 4 480 491 510 485 495 472 417 474 502 476 ... 491  480  474  572  454  469
# 5 484 502 528 489 466 481 402 478 487 468 ... 488  479  452  435  486  508
# 6 481 496 451 480 516 484 484 476 500 482 ... 478  481  477  435  491  564
#   V497 V498 V499 V500
# 1 481  479  475  496
# 2 483  492  510  517
# 3 480  489  499  498
# 4 475  482  494  461
# 5 481  504  495  511
# 6 482  463  457  500

# %%
# Size of data set
dim(data)
# Out:
# [1] 2000  500

# %%
# Memory footprint
object.size(data)
# Out:
# 4052568 bytes

# %%
# Data Type
sapply(data, typeof)
# Out:
#        V1        V2        V3        V4        V5        V6        V7        V8
# "integer" "integer" "integer" "integer" "integer" "integer" "integer" "integer"
#        V9       V10       V11       V12       V13       V14       V15       V16
# "integer" "integer" "integer" "integer" "integer" "integer" "integer" "integer"
#       V17       V18       V19       V20       V21       V22       V23       V24
# "integer" "integer" "integer" "integer" "integer" "integer" "integer" "integer"
#       V25       V26       V27       V28       V29       V30       V31       V32
# "integer" "integer" "integer" "integer" "integer" "integer" "integer" "integer"
#       V33       V34       V35       V36       V37       V38       V39       V40
# "integer" "integer" "integer" "integer" "integer" "integer" "integer" "integer"
#       V41       V42       V43       V44       V45       V46       V47       V48
# "integer" "integer" "integer" "integer" "integer" "integer" "integer" "integer"
# ...

# %%
# Summary Statistics
dataMean <- apply(data, 2, mean)
dataMedian <- apply(data, 2, median)
dataSD <- apply(data, 2, sd)
# Out:
#       V1       V2       V3       V4       V5       V6       V7       V8
# 481.7225 483.4525 510.1660 483.3845 501.6125 479.2590 480.1095 476.5650
#       V9      V10      V11      V12      V13      V14      V15      V16
# 486.7935 478.7890 486.5175 490.6535 478.1645 481.5245 485.0385 479.4235
#      V17      V18      V19      V20      V21      V22      V23      V24
# 479.2870 494.9475 484.1730 477.4270 484.7145 494.2390 476.5730 479.2605
#      V25      V26      V27      V28      V29      V30      V31      V32
# 499.4075 504.7190 484.7835 482.0995 480.5975 491.9145 481.9315 500.0370
#      V33      V34      V35      V36      V37      V38      V39      V40
# 500.6095 489.5455 486.7130 489.1280 479.0460 480.6700 479.8000 476.1530
#      V41      V42      V43      V44      V45      V46      V47      V48
# 476.4925 489.4840 476.5660 487.8925 500.3040 480.4390 496.6275 494.7715
#      V49      V50      V51      V52      V53      V54      V55      V56
# ...

# %%
# Plots
hist(dataMean, col = 'light blue')
plot(density(data.matrix(data)))
hist(dataMedian, col = 'light green')
# Out:
# Plot with title "Histogram of dataMean"
# Plot with title "Histogram of dataMedian"
